# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import os
import pandas as pd
import seaborn as sns
import itertools as iter
import gc
from collections import Counter

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ['orders.csv', 'departments.csv', 'products.csv', 'sample_submission.csv', 'order_products__train.csv', 'order_products__prior.csv', 'aisles.csv']

# %%
products = pd.read_csv("../input/products.csv",dtype={
        'product_id': np.uint16,
        'product_name': object,
        'aisle_id': np.uint8,
        'department_id': np.uint8})

departments = pd.read_csv("../input/departments.csv",dtype={
        'department_id': np.uint16,
        'department_name': object})
aisles = pd.read_csv("../input/aisles.csv",dtype={
        'aisle_id': np.uint16,
        'aisle_name': object})
orders = pd.read_csv("../input/orders.csv", dtype={
        'order_id': np.int32,
        'user_id': np.int32,
        'eval_set': object,
        'order_number': np.int16,
        'order_dow': np.int8,
        'order_hour_of_day': np.int8,
        'days_since_prior_order': np.float32})
order_products_train = pd.read_csv("../input/order_products__train.csv", dtype={
            'order_id': np.int32,
            'product_id': np.uint16,
            'add_to_cart_order': np.int16,
            'reordered': np.int8})
order_products_prior = pd.read_csv("../input/order_products__prior.csv", dtype={
            'order_id': np.int32,
            'product_id': np.uint16,
            'add_to_cart_order': np.int16,
            'reordered': np.int8})

# %%
items  = pd.merge(left =pd.merge(left=products, right=departments, how='left', on = 'department_id'), right=aisles, how='left', on = 'aisle_id')
prior_data = orders.merge(order_products_prior,how='inner', left_on='order_id', right_on='order_id').drop(columns=['eval_set'])
prior_data = prior_data.merge(items,how='inner', left_on='product_id', right_on='product_id')
train_data = orders.merge(order_products_train,how='inner', left_on='order_id', right_on='order_id').drop(columns=['eval_set'])
train_data = train_data.merge(items,how='inner', left_on='product_id', right_on='product_id')

# %%
ordersTrain=orders[orders['eval_set']=='train']
print(len(ordersTrain))
train_usr = pd.DataFrame(ordersTrain['user_id'].unique(), columns =['user_id'])
train_usr_sample =  train_usr.sample(2500, random_state=42).sort_values('user_id').reset_index(drop = True)
orders=orders[orders['user_id'].isin(train_usr_sample['user_id'])]
orders.head(5)
# Out:
# 131209
#       order_id           ...            days_since_prior_order
# 4564   2006537           ...                               NaN
# 4565    983957           ...                              12.0
# 4566   2314173           ...                              14.0
# 4567    106356           ...                              10.0
# 4568   1801937           ...                              14.0
#
# [5 rows x 7 columns]

# %%
#Creating Training Dataset
train_data = prior_data.merge(train_usr_sample,how='inner', left_on='user_id', right_on='user_id')
train_data['user_id'].nunique()
# Out:
# 2500

# %%
order_product = train_data[['order_id','product_name']]
order_product.head()
# Out:
#    order_id product_name
# 0   1422524         Soda
# 1   3306294         Soda
# 2     48682         Soda
# 3   2214144         Soda
# 4    903609         Soda

# %%
order_product['product_number'] = order_product.groupby(['order_id']).cumcount()+1
order_product = order_product.sort_values(by=['order_id','product_number'])
order_product.head()
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#        order_id          product_name  product_number
# 62596        56  Organic Hass Avocado               1
# 62608        56  Organic Baby Spinach               2
# 62716        56   Large Alfresco Eggs               3
# 62740        56     Shredded Parmesan               4
# 62814        56           Blueberries               5

# %%
order_product = order_product.pivot(index='order_id', columns='product_number', values='product_name')
order_product.head()
# Out:
# product_number                      1  ...    84
# order_id                               ...
# 56                Organic Hass Avocado ...   NaN
# 105             Bag of Organic Bananas ...   NaN
# 154                    Original Hummus ...   NaN
# 210                   Honeycrisp Apple ...   NaN
# 216               Organic Strawberries ...   NaN
#
# [5 rows x 84 columns]

# %%
op_index = order_product.index.values
product_list =  order_product.apply(lambda x :'*_*'.join(x.fillna("xxx").astype(str)),1)
product_list.index = op_index
order_product['product'] = product_list
order_product
# Out:
# product_number                                                  1                        ...                                                                    product
# order_id                                                                                 ...
# 56                                           Organic Hass Avocado                        ...                          Organic Hass Avocado*_*Organic Baby Spinach*_*...
# 105                                        Bag of Organic Bananas                        ...                          Bag of Organic Bananas*_*Seedless Red Grapes*_...
# 154                                               Original Hummus                        ...                          Original Hummus*_*White Cheddar Macaroni & Che...
# 210                                              Honeycrisp Apple                        ...                          Honeycrisp Apple*_*Brussels Sprouts*_*Organic ...
# 216                                          Organic Strawberries                        ...                          Organic Strawberries*_*Pure Sparkling Water*_*...
# 298                                  Almond Milk Blueberry Yogurt                        ...                          Almond Milk Blueberry Yogurt*_*Ice*_*Plain Alm...
# 350                                        Bag of Organic Bananas                        ...                          Bag of Organic Bananas*_*Organic Gala Apples*_...
# 422                                         Organic Russet Potato                        ...                          Organic Russet Potato*_*Extra Virgin Olive Oil...
# 578                                           Organic Raspberries                        ...                          Organic Raspberries*_*All Natural No Stir Crea...
# 595                                    Lactose Free Fat Free Milk                        ...                          Lactose Free Fat Free Milk*_*Limes*_*Red Peppe...
# 606                                        Bag of Organic Bananas                        ...                          Bag of Organic Bananas*_*Apple Honeycrisp Orga...
# 802                                           Organic Blueberries                        ...                          Organic Blueberries*_*xxx*_*xxx*_*xxx*_*xxx*_*...
# 828                                           Organic Half & Half                        ...                          Organic Half & Half*_*Miniatures Assortment Pa...
# 865                                          Organic Strawberries                        ...                          Organic Strawberries*_*Organic Zucchini*_*Orga...
# 914                                           Seedless Red Grapes                        ...                          Seedless Red Grapes*_*Organic Small Bunch Cele...
# 922                                                        Banana                        ...                          Banana*_*Extra Virgin Olive Oil*_*Sandwich Bag...
# 994                                                Bartlett Pears                        ...                          Bartlett Pears*_*Strawberries*_*Banana*_*Organ...
# 1007                                       Bag of Organic Bananas                        ...                          Bag of Organic Bananas*_*Organic Avocado*_*Ori...
# 1167                              Organic Unsweetened Almond Milk                        ...                          Organic Unsweetened Almond Milk*_*Walnut Halve...
# 1213                                         Organic Strawberries                        ...                          Organic Strawberries*_*Reduced Fat 2% Milk*_*B...
# 1345                  Organic Grade A Free Range Large Brown Eggs                        ...                          Organic Grade A Free Range Large Brown Eggs*_*...
# 1448                                                         Soda                        ...                          Soda*_*Zero Calorie Cola*_*Dried Mangos*_*Trai...
# 1488                                         Organic Yellow Onion                        ...                          Organic Yellow Onion*_*Organic No Salt Added D...
# 1512                    Swaddlers Diapers Jumbo Pack Size Newborn                        ...                          Swaddlers Diapers Jumbo Pack Size Newborn*_*xx...
# 1617                                                       Banana                        ...                          Banana*_*Organic Beans & Rice Cheddar Cheese B...
# 1649                                       Extra Virgin Olive Oil                        ...                          Extra Virgin Olive Oil*_*Organic Lemon*_*Organ...
# 1694                                       Salsa Con Queso Medium                        ...                          Salsa Con Queso Medium*_*Meat & Cheese Tray*_*...
# 1767                                           Small Hass Avocado                        ...                          Small Hass Avocado*_*Fresh CA Grown Eggs*_*Vod...
# 1854                                       Bag of Organic Bananas                        ...                          Bag of Organic Bananas*_*Organic Raspberries*_...
# 1896                                           Cabernet Sauvignon                        ...                          Cabernet Sauvignon*_*xxx*_*xxx*_*xxx*_*xxx*_*x...
# ...                                                           ...                        ...                                                                        ...
# 3418566                                          Organic Cilantro                        ...                          Organic Cilantro*_*Blood Oranges*_*Organic Ita...
# 3418646                                    Walnut Halves & Pieces                        ...                          Walnut Halves & Pieces*_*Limes*_*Carrots*_*Gar...
# 3419044                                           Original Hummus                        ...                          Original Hummus*_*Organic Large Extra Fancy Fu...
# 3419051                                100% Recycled Paper Towels                        ...                          100% Recycled Paper Towels*_*Uncured Slow Cook...
# 3419090                                                    Banana                        ...                          Banana*_*Organic Red Onion*_*Michigan Organic ...
# 3419099                           Organic Unsweetened Almond Milk                        ...                          Organic Unsweetened Almond Milk*_*Organic Zucc...
# 3419148                                Sparkling Water Grapefruit                        ...                          Sparkling Water Grapefruit*_*Clementines, Bag*...
# 3419180                                       Lemonade Fruit Bars                        ...                          Lemonade Fruit Bars*_*xxx*_*xxx*_*xxx*_*xxx*_*...
# 3419235         Organic Sticks Low Moisture Part Skim Mozzarel...                        ...                          Organic Sticks Low Moisture Part Skim Mozzarel...
# 3419325                                                    Banana                        ...                          Banana*_*Organic Garnet Sweet Potato (Yam)*_*O...
# 3419358                          Vintners Reserve Sauvignon Blanc                        ...                          Vintners Reserve Sauvignon Blanc*_*xxx*_*xxx*_...
# 3419371                                Unsalted Pure Irish Butter                        ...                          Unsalted Pure Irish Butter*_*Alpine Spring Wat...
# 3419376                                       Organic Raspberries                        ...                          Organic Raspberries*_*Organic Baby Carrots*_*S...
# 3419517                                                    Banana                        ...                          Banana*_*2% Reduced Fat Milk*_*Original Almond...
# 3419756                                        Raspberry Lemonade                        ...                          Raspberry Lemonade*_*Real Fruit Juice Snacks*_...
# 3419847         Organic Sticks Low Moisture Part Skim Mozzarel...                        ...                          Organic Sticks Low Moisture Part Skim Mozzarel...
# 3419857                                    Bag of Organic Bananas                        ...                          Bag of Organic Bananas*_*Organic Broccoli Flor...
# 3419879                                       Organic Raspberries                        ...                          Organic Raspberries*_*Organic Hass Avocado*_*O...
# 3419984                                              Strawberries                        ...                          Strawberries*_*Raspberries*_*Blackberries*_*Go...
# 3420031                                                      Soda                        ...                          Soda*_*Mixed Vegetables*_*Cheese Natural Slice...
# 3420123                                         Macaroni & Cheese                        ...                          Macaroni & Cheese*_*Traditional Refried Beans*...
# 3420180                                           Organic Avocado                        ...                          Organic Avocado*_*Banana*_*Organic Baby Spinac...
# 3420212                                    Bag of Organic Bananas                        ...                          Bag of Organic Bananas*_*Original Hummus*_*Str...
# 3420281                        Total 2% Lowfat Plain Greek Yogurt                        ...                          Total 2% Lowfat Plain Greek Yogurt*_*Organic W...
# 3420482                                                    Banana                        ...                          Banana*_*Extra Virgin Olive Oil*_*Double Stuf ...
# 3420559             Icelandic Style Skyr Blueberry Non-fat Yogurt                        ...                          Icelandic Style Skyr Blueberry Non-fat Yogurt*...
# 3420645                        Gluten Free Mediterranean Crackerz                        ...                          Gluten Free Mediterranean Crackerz*_*xxx*_*xxx...
# 3420650                   Organic Unsweetened Vanilla Almond Milk                        ...                          Organic Unsweetened Vanilla Almond Milk*_*Orga...
# 3420707                                          Honeycrisp Apple                        ...                          Honeycrisp Apple*_*Strawberries*_*Unsalted But...
# 3421017                                          3 lb Clementines                        ...                          3 lb Clementines*_*xxx*_*xxx*_*xxx*_*xxx*_*xxx...
#
# [41007 rows x 85 columns]

# %%
order_product['order_id'] = order_product.index
order_product = order_product[['order_id','product']]
order_product.head()
# Out:
# product_number  order_id                                            product
# order_id
# 56                    56  Organic Hass Avocado*_*Organic Baby Spinach*_*...
# 105                  105  Bag of Organic Bananas*_*Seedless Red Grapes*_...
# 154                  154  Original Hummus*_*White Cheddar Macaroni & Che...
# 210                  210  Honeycrisp Apple*_*Brussels Sprouts*_*Organic ...
# 216                  216  Organic Strawberries*_*Pure Sparkling Water*_*...

# %%
op = order_product.values
for i in range(len(op)):
    l = list(set(op[i][1].split('*_*')))
    if ('xxx' in l):
        l.remove('xxx')
    l = list(iter.combinations(l,2))
    op[i][1] = l

# %%
op_df = pd.DataFrame(op, columns=['order_id','product_pairs'])
op_df.head()
# Out:
#   order_id                                      product_pairs
# 0       56  [(Organic Garlic, Organic Tomato Paste), (Orga...
# 1      105  [(Whole Milk With Vitamin D, Chocolate Chip Co...
# 2      154  [(Cold Pressed Watermelon & Lemon Juice Blend,...
# 3      210  [(Organic Unsalted Butter, Dried Mango), (Orga...
# 4      216  [(Organic Pure 85% Dark Chocolate Bar, Orange ...

# %%
# del products
del departments
del aisles
del orders
del order_products_train
del order_products_prior
del items
del order_product
del prior_data

# %%
import gc
gc.collect()
# Out:
# 61

# %%
res = op_df.apply(lambda x: pd.Series(x['product_pairs']),axis=1).stack().reset_index(level=1, drop=True)
res.name = 'product_pair'

# %%
op_df = op_df.drop('product_pairs', axis=1).join(res)
op_df.head()
# Out:
#   order_id                                    product_pair
# 0       56          (Organic Garlic, Organic Tomato Paste)
# 0       56  (Organic Garlic, Coconut Almond Creamer Blend)
# 0       56                   (Organic Garlic, Blueberries)
# 0       56          (Organic Garlic, Organic Baby Spinach)
# 0       56          (Organic Garlic, Organic Hass Avocado)

# %%
op_df['order_id']=op_df['order_id'].astype('int64')

# %%
del res
gc.collect()
# Out:
# 287082

# %%
train_data = train_data[['user_id','order_id']]
train_data.head()
# Out:
#    user_id  order_id
# 0     4028   1422524
# 1     4028   3306294
# 2     4028     48682
# 3     4028   2214144
# 4     4028    903609

# %%
up_df = train_data.merge(op_df, how='inner', on='order_id')

# %%
up_df = up_df.dropna()

# %%
del op_df
del train_data
gc.collect()
# Out:
# 32

# %%
up_df.head()
up_df.shape
# Out:
# (64658133, 3)

# %%
up_df['user_id'].nunique()
# Out:
# 2488

# %%
users = list(set(up_df['user_id']))
user_set1 = users[0:311*1]
user_set2 = users[311*1:311*2]
user_set3 = users[311*2:311*3]
user_set4 = users[311*3:311*4]
user_set5 = users[311*4:311*5]
user_set6 = users[311*5:311*6]
user_set7 = users[311*6:311*7]
user_set8 = users[311*7:311*8]

# %%
up_df1 = up_df[up_df['user_id'].isin(user_set1)]
up_df2 = up_df[up_df['user_id'].isin(user_set2)]
up_df3 = up_df[up_df['user_id'].isin(user_set3)]
up_df4 = up_df[up_df['user_id'].isin(user_set4)]
up_df5 = up_df[up_df['user_id'].isin(user_set5)]
up_df6 = up_df[up_df['user_id'].isin(user_set6)]
up_df7 = up_df[up_df['user_id'].isin(user_set7)]
up_df8 = up_df[up_df['user_id'].isin(user_set8)]

# %%
del user_set1
del user_set2
del user_set3
del user_set4
del user_set5
del user_set6
del user_set7
del user_set8

# del users
# del up_df
gc.collect()
# Out:
# 0

# %%
up_df1 = pd.crosstab(up_df1.user_id,up_df1.product_pair)
#up_df1.to_csv(r'crtb1.csv')
#del up_df1
up_df1.shape
# Out:
# (311, 242793)

# %%
# up_df2 = pd.crosstab(up_df2.user_id,up_df2.product_pair)
# up_df2.to_csv(r'crtb2.csv')
# del up_df2
# gc.collect()

# %%
# up_df3 = pd.crosstab(up_df3.user_id,up_df3.product_pair)
# #up_df2.to_csv(r'crtb2.csv')
# #del up_df3
# gc.collect()

# %%
# up_df4 = pd.crosstab(up_df4.user_id,up_df4.product_pair)
# #up_df2.to_csv(r'crtb2.csv')
# #del up_df3
# gc.collect()

# %%
# up_df5 = pd.crosstab(up_df5.user_id,up_df5.product_pair)
# #up_df2.to_csv(r'crtb2.csv')
# #del up_df3
# gc.collect()

# %%
# up_df6 = pd.crosstab(up_df6.user_id,up_df6.product_pair)
# #up_df2.to_csv(r'crtb2.csv')
# #del up_df3
# gc.collect()

# %%
# up_df7 = pd.crosstab(up_df7.user_id,up_df7.product_pair)
# #up_df2.to_csv(r'crtb2.csv')
# #del up_df3
# gc.collect()

# %%
# up_df8 = pd.crosstab(up_df8.user_id,up_df8.product_pair)
# #up_df2.to_csv(r'crtb2.csv')
# #del up_df3
# gc.collect()
